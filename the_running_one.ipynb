# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsMeBerk/MachineLearningCourse/blob/main/the_running_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.2.2'

# %%
def fetch_financial_data(company='AON'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#               Open    High      Low   Close     Volume
# Date
# 2023-08-30  333.36  335.84  332.290  334.63   490384.0
# 2023-08-29  332.00  333.30  329.430  333.20   446601.0
# 2023-08-28  331.94  333.75  329.485  331.51   540741.0
# 2023-08-25  330.00  334.26  328.915  332.07  1041480.0
# 2023-08-24  326.23  328.55  322.950  327.03   425525.0

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2023-08-30 to 2023-08-24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0 bytes

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#               Open    High      Low   Close     Volume  day  month  year
# Date
# 2023-08-30  333.36  335.84  332.290  334.63   490384.0   30      8  2023
# 2023-08-29  332.00  333.30  329.430  333.20   446601.0   29      8  2023
# 2023-08-28  331.94  333.75  329.485  331.51   540741.0   28      8  2023
# 2023-08-25  330.00  334.26  328.915  332.07  1041480.0   25      8  2023
# 2023-08-24  326.23  328.55  322.950  327.03   425525.0   24      8  2023

# %%
df['High/Close'] = df['High']/df['Close']
df
# Out:
#               Open    High      Low   Close     Volume  day  month  year  \
# Date
# 2023-08-30  333.36  335.84  332.290  334.63   490384.0   30      8  2023
# 2023-08-29  332.00  333.30  329.430  333.20   446601.0   29      8  2023
# 2023-08-28  331.94  333.75  329.485  331.51   540741.0   28      8  2023
# 2023-08-25  330.00  334.26  328.915  332.07  1041480.0   25      8  2023
# 2023-08-24  326.23  328.55  322.950  327.03   425525.0   24      8  2023
#
#             High/Close
# Date
# 2023-08-30    1.003616
# 2023-08-29    1.000300
# 2023-08-28    1.006757
# 2023-08-25    1.006595
# 2023-08-24    1.004648

# %%
def standarize(x):
  return (x - x.mean()) / x.std()

standarize(df['High/Close'])
# Out:
# Date
# 2023-08-30   -0.290735
# 2023-08-29   -1.547206
# 2023-08-28    0.899503
# 2023-08-25    0.838129
# 2023-08-24    0.100308
# Name: High/Close, dtype: float64

# %%
df
# Out:
#               Open    High      Low   Close     Volume  day  month  year  \
# Date
# 2023-08-30  333.36  335.84  332.290  334.63   490384.0   30      8  2023
# 2023-08-29  332.00  333.30  329.430  333.20   446601.0   29      8  2023
# 2023-08-28  331.94  333.75  329.485  331.51   540741.0   28      8  2023
# 2023-08-25  330.00  334.26  328.915  332.07  1041480.0   25      8  2023
# 2023-08-24  326.23  328.55  322.950  327.03   425525.0   24      8  2023
#
#             High/Close
# Date
# 2023-08-30    1.003616
# 2023-08-29    1.000300
# 2023-08-28    1.006757
# 2023-08-25    1.006595
# 2023-08-24    1.004648

# %%
from sklearn.preprocessing import scale

scale(df['High/Close'])
# Out:
# array([-0.32505137, -1.72982836,  1.00567523,  0.93705694,  0.11214756])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(df[['High/Close']])
scaler.transform(df[['High/Close']])
# Out:
# array([[-0.32505137],
#        [-1.72982836],
#        [ 1.00567523],
#        [ 0.93705694],
#        [ 0.11214756]])

# %%
scaler = StandardScaler()
df['High/Close'] = scaler.fit_transform(df[['High/Close']])
df
# Out:
#               Open    High      Low   Close     Volume  day  month  year  \
# Date
# 2023-08-30  333.36  335.84  332.290  334.63   490384.0   30      8  2023
# 2023-08-29  332.00  333.30  329.430  333.20   446601.0   29      8  2023
# 2023-08-28  331.94  333.75  329.485  331.51   540741.0   28      8  2023
# 2023-08-25  330.00  334.26  328.915  332.07  1041480.0   25      8  2023
# 2023-08-24  326.23  328.55  322.950  327.03   425525.0   24      8  2023
#
#             High/Close
# Date
# 2023-08-30   -0.325051
# 2023-08-29   -1.729828
# 2023-08-28    1.005675
# 2023-08-25    0.937057
# 2023-08-24    0.112148
